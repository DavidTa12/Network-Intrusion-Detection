# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("network_intrusion_attack.csv",low_memory=False)
#display(df)

# %%
df.columns=[
'Duration (seconds)', 
'Connection protocol type', 
'Destination network service used',
'Flag statut of connection ',
'Number of data bytes transferred from source to destination',
'Number of data bytes transferred from destination to source', 
'From same country',
'Total number of wrong fragments',
'Number of urgent packets', 
'Number of HOT indicators in the content',
'Count of failed login attempts', 
'Login Status', 
'Number of compromised conditions', 
'If root shell is obtained',
'If su root command attempted', 
'Number of root accesses',
'Number of file creation operations',
'Number of shell prompts',
'Number of operations on access control files', 
'Number of outbound commands in an ftp session',
'Logged as host',
'Logged as guest', 
'Count: Number of connections to the same destination host as the current connection in the past twoseconds', 
'Srvcount: Number of connections to the same service (port number) as the current connection in the past two seconds', 
'Serrorrate: The percentage of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in count (23)', 
'Srvserrorrate: The percentage of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in srvcount (24)', 
'Rerrorrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in count', 
'Srvrerrorrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in srvcount', 
'Samesrvrate: The percentage of connections that were to the same service, among the connections aggregated in count', 
'Diffsrvrate: The percentage of connections that were to different services, among the connections aggregated in count', 
'Srvdiffhost rate: The percentage of connections that were to different destination machines among the connections aggregated in srvcount (24) HOST BASED TRAFFIC FEATURES IN A NETWORK CONNECTION VECTOR', 
'Dsthostcount: Number of connections having the same destination host IP address', 
'Dsthostsrv count: Number of connections having the same port number',
'Dsthostsame srvrate: The percentage of connections that were to the same service, among the connections aggregated in dsthostcount',
'Dsthostdiff_ srvrate: The percentage of connections that were to different services, among the connections aggregated in dsthostcount', 
'Dsthost_same _srcportrate: The percentage of connections that were to the same source port, among the connections aggregated in dsthostsrvc ount', 
'Dsthostsrv diffhostrate: The percentage of connections that were to different destination machines, among the connections aggregated in dsthostsrvcount', 
'Dsthostserro rrate: The percentage of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in dsthostcount', 
'Dsthostsrvs errorrate: The percent of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in dsthostsrvc ount',
'Dsthostrerro rrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in dsthostcount', 
'Dsthostsrvr errorrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in dsthostsrv_count',
'GOAL: type of activity']

# %%
df = df[[
'GOAL: type of activity',
'Duration (seconds)', 
'From same country', 
'Login Status',
'If root shell is obtained',
'If su root command attempted', 
'Logged as host',
'Logged as guest', 
'Connection protocol type', 
'Destination network service used',
'Flag statut of connection ',
'Number of data bytes transferred from source to destination',
'Number of data bytes transferred from destination to source',  
'Total number of wrong fragments',
'Number of urgent packets', 
'Number of HOT indicators in the content',
'Count of failed login attempts', 
'Number of compromised conditions',  
'Number of root accesses', 
'Number of file creation operations',
'Number of shell prompts',
'Number of operations on access control files', 
'Number of outbound commands in an ftp session',
'Count: Number of connections to the same destination host as the current connection in the past twoseconds', 
'Srvcount: Number of connections to the same service (port number) as the current connection in the past two seconds', 
'Serrorrate: The percentage of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in count (23)', 
'Srvserrorrate: The percentage of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in srvcount (24)', 
'Rerrorrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in count', 
'Srvrerrorrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in srvcount', 
'Samesrvrate: The percentage of connections that were to the same service, among the connections aggregated in count', 
'Diffsrvrate: The percentage of connections that were to different services, among the connections aggregated in count', 
'Srvdiffhost rate: The percentage of connections that were to different destination machines among the connections aggregated in srvcount (24) HOST BASED TRAFFIC FEATURES IN A NETWORK CONNECTION VECTOR', 
'Dsthostcount: Number of connections having the same destination host IP address', 
'Dsthostsrv count: Number of connections having the same port number',
'Dsthostsame srvrate: The percentage of connections that were to the same service, among the connections aggregated in dsthostcount',
'Dsthostdiff_ srvrate: The percentage of connections that were to different services, among the connections aggregated in dsthostcount', 
'Dsthost_same _srcportrate: The percentage of connections that were to the same source port, among the connections aggregated in dsthostsrvc ount', 
'Dsthostsrv diffhostrate: The percentage of connections that were to different destination machines, among the connections aggregated in dsthostsrvcount', 
'Dsthostserro rrate: The percentage of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in dsthostcount', 
'Dsthostsrvs errorrate: The percent of connections that have activated the flag (4) s0, s1, s2 or s3, among the connections aggregated in dsthostsrvc ount', 
'Dsthostrerro rrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in dsthostcount', 
'Dsthostsrvr errorrate: The percentage of connections that have activated the flag (4) REJ, among the connections aggregated in dsthostsrv_count']]
df.dropna(axis=0, inplace=True)

# %%
display(df)
# Out:
#       GOAL: type of activity  Duration (seconds)  From same country  \
# 0                     normal                   0                  0
# 1                     normal                   0                  0
# 2                    anomaly                   0                  0
# 3                     normal                   0                  0
# 4                     normal                   0                  0
# ...                      ...                 ...                ...
# 25187                anomaly                   0                  0
# 25188                anomaly                   0                  0
# 25189                anomaly                   0                  0
# 25190                anomaly                   0                  0
# 25191                anomaly                   0                  0
#
#        Login Status  If root shell is obtained  If su root command attempted  \
# ...

# %%
df.loc[(df['From same country'] == 0),'From same country']='No'
df.loc[(df['From same country'] == 1),'From same country']='Yes'
df.loc[(df['Login Status'] == 0),'Login Status']='Disconnected'
df.loc[(df['Login Status'] == 1),'Login Status']='Connected'
df.loc[(df['If root shell is obtained'] == 0),'If root shell is obtained']='No'
df.loc[(df['If root shell is obtained'] == 1),'If root shell is obtained']='Yes'
df.loc[(df['If su root command attempted'] == 0),'If su root command attempted']='No'
df.loc[(df['If su root command attempted'] == 1),'If su root command attempted']='Yes'
df.loc[(df['Logged as host'] == 0),'Logged as host']='No'
df.loc[(df['Logged as host'] == 1),'Logged as host']='Yes'
df.loc[(df['Logged as guest'] == 0),'Logged as guest']='No'
df.loc[(df['Logged as guest'] == 1),'Logged as guest']='Yes'

display(df)
# Out:
#       GOAL: type of activity  Duration (seconds) From same country  \
# 0                     normal                   0                No
# 1                     normal                   0                No
# 2                    anomaly                   0                No
# 3                     normal                   0                No
# 4                     normal                   0                No
# ...                      ...                 ...               ...
# 25187                anomaly                   0                No
# 25188                anomaly                   0                No
# 25189                anomaly                   0                No
# 25190                anomaly                   0                No
# 25191                anomaly                   0                No
#
#        Login Status If root shell is obtained If su root command attempted  \
# 0      Disconnected                        No                           No
# ...

# %%
df.to_csv(r'/Users/davidta/Desktop/Jupyter/test.csv', index = False)

# %%
#df.loc[df['From same country'] != '0', 'test'] = 'True'

# %%
#df.drop_duplicates('Logged as host', keep='first')
# pour garder les valeurs uniques d'une colonne, idéal pour connaitre les variables possibles

# %%
#df.loc[df['Login Status'] != 0]
# pour garder les rows qui ont un Login Status différent de 0

# %%
#print(df.to_string())
#pour print tout le dataframe
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
